# %%
import numpy as np
from tqdm import tqdm
import logging

logging.basicConfig()
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
import pandas as pd

# %%
#_num_tuples = 1296
#_num_features = 11
#_label_dims = 45
_num_tuples = 1296
_num_features = 45
_label_dims = 11

# %%
# deprecated
def load_data(files, num_tuples, num_features, label_dims):
    data_file, label_file = files

    data = np.zeros((num_tuples, num_features))
    labels = np.zeros((num_tuples, label_dims))
    
    with open(data_file, 'rb') as f:
        for i,line in enumerate(f.readlines()):
            ##################[ISSUE! @YUZHE]HARD CODED, PLEASE CHECK THE DATA FORMAT ########################
            processed = line.rstrip('\n').rstrip('\r').rstrip(',,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,').split(',')
            ###################################################################################################
            #logger.info(processed)
            try:
                assert num_features == len(processed)
                data[i,:] = processed
            except AssertionError as err:
                logger.info("Wrong Feature Number claimed !, {}, {}".format(num_features, len(processed)))
                
    with open(label_file, 'rb') as f:
        for i,line in enumerate(f.readlines()):
            processed = line.rstrip('\n').split(',')
            try:
                assert label_dims == len(processed)
                labels[i,:] = processed
            except AssertionError as err:
                logger.info("Wrong Label Dimensions claimed !")
        return data, labels

# %%
data = pd.read_excel('spectrum.xlsx').values
labels = pd.read_excel('temperature.xlsx').values

# %%
# deprecated
#data, labels = load_data(('temperature.csv', 'spectrum.csv'), _num_tuples, _num_features, _label_dims)

# %%
class Dataset(object):
    def __init__(self, data):
        # m, n denote number of tuples and features respectively
        self._m = data[0].shape[0]
        self._n = data[0].shape[1]
        self._training_data = data[0]
        self._training_labels = data[1]
        
    def __len__(self):
        return self._m
    
    def __getitem__(self, idx):
        return  self._training_data[idx,:], self._training_labels[idx,:] 

    def fetch_col(self, col_index):
        return self._training_data[:, col_index]

    def shuffle(self, seed=None):
        if seed:
            np.random.seed(seed=seed)
        shuffled_indices = np.arange(self._m)
        np.random.shuffle(shuffled_indices)
        self._training_data = np.take(self._training_data, shuffled_indices, axis=0)
        self._training_labels = np.take(self._training_labels, shuffled_indices)

    @property
    def num_tuples(self):
        return self._m

    @property
    def num_features(self):
        return self._n

    @property
    def labels(self):
        return self._training_labels

    @property
    def data_table(self):
        return self._training_data

# %%
dataset = Dataset((data, labels))

# %%
import torch
from torch import nn

# model definition
class NN(nn.Module):
    def __init__(self):
        super(NN, self).__init__()
        self.fc1 = nn.Linear(45, 100)
        self.fc2 = nn.Linear(100, 100)
        self.fc3= nn.Linear(100, 11)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.fc3(x)
        #x = self.sigmoid(x)
        return x
    def name(self):
        return 'nn'

# %%
from torch.utils.data import DataLoader
import torch.nn.functional as F

args = {'lr':1e-5, 
        'max_steps':1000,
        'batch_size':128,
        'epoch':30,
        'enable_gpu':None}
train_loader = DataLoader(dataset, batch_size=args['batch_size'], shuffle=True)

# %%
import torch.optim as optim

device = torch.device("cpu")
model = NN().to(device)
optimizer = optim.SGD(model.parameters(), lr=args['lr'], momentum=0.9)

# %%
def train(args, model, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in tqdm(enumerate(train_loader)):
        data, target = data.float().to(device), target.float().to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.mse_loss(output, target)
        loss.backward()
        optimizer.step()
        logger.info('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

def test(args, model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.mse_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    logger.info('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
for epoch in range(1, args['epoch'] + 1):
    train(args, model, device, train_loader, optimizer, epoch)
    #test(args, model, device, test_loader)
# Out:
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 1 [0/1295 (0%)]	Loss: 402965.062500
# 1it [00:00,  1.78it/s]INFO:root:Train Epoch: 1 [128/1295 (9%)]	Loss: 405157.625000
# INFO:root:Train Epoch: 1 [256/1295 (18%)]	Loss: 392336.281250
# INFO:root:Train Epoch: 1 [384/1295 (27%)]	Loss: 401939.750000
# INFO:root:Train Epoch: 1 [512/1295 (36%)]	Loss: 398738.281250
# INFO:root:Train Epoch: 1 [640/1295 (45%)]	Loss: 353997.062500
# INFO:root:Train Epoch: 1 [768/1295 (55%)]	Loss: 4415.960938
# INFO:root:Train Epoch: 1 [896/1295 (64%)]	Loss: 815704.250000
# INFO:root:Train Epoch: 1 [1024/1295 (73%)]	Loss: 580042.437500
# INFO:root:Train Epoch: 1 [1152/1295 (82%)]	Loss: 408742.656250
# INFO:root:Train Epoch: 1 [150/1295 (91%)]	Loss: 367987.156250
# 11it [00:00, 17.51it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 2 [0/1295 (0%)]	Loss: 389390.437500
# INFO:root:Train Epoch: 2 [128/1295 (9%)]	Loss: 397122.968750
# INFO:root:Train Epoch: 2 [256/1295 (18%)]	Loss: 402334.156250
# INFO:root:Train Epoch: 2 [384/1295 (27%)]	Loss: 390754.281250
# INFO:root:Train Epoch: 2 [512/1295 (36%)]	Loss: 377894.687500
# INFO:root:Train Epoch: 2 [640/1295 (45%)]	Loss: 365032.531250
# INFO:root:Train Epoch: 2 [768/1295 (55%)]	Loss: 294616.000000
# INFO:root:Train Epoch: 2 [896/1295 (64%)]	Loss: 154964.078125
# INFO:root:Train Epoch: 2 [1024/1295 (73%)]	Loss: 3238.715576
# INFO:root:Train Epoch: 2 [1152/1295 (82%)]	Loss: 233560.640625
# INFO:root:Train Epoch: 2 [150/1295 (91%)]	Loss: 117925.429688
# 11it [00:00, 166.62it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 3 [0/1295 (0%)]	Loss: 8397.747070
# INFO:root:Train Epoch: 3 [128/1295 (9%)]	Loss: 111864.703125
# INFO:root:Train Epoch: 3 [256/1295 (18%)]	Loss: 167417.765625
# INFO:root:Train Epoch: 3 [384/1295 (27%)]	Loss: 132059.515625
# INFO:root:Train Epoch: 3 [512/1295 (36%)]	Loss: 34813.589844
# INFO:root:Train Epoch: 3 [640/1295 (45%)]	Loss: 24435.837891
# INFO:root:Train Epoch: 3 [768/1295 (55%)]	Loss: 139119.843750
# INFO:root:Train Epoch: 3 [896/1295 (64%)]	Loss: 23981.029297
# INFO:root:Train Epoch: 3 [1024/1295 (73%)]	Loss: 21845.986328
# INFO:root:Train Epoch: 3 [1152/1295 (82%)]	Loss: 79610.585938
# INFO:root:Train Epoch: 3 [150/1295 (91%)]	Loss: 80284.250000
# 11it [00:00, 164.13it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 4 [0/1295 (0%)]	Loss: 29718.003906
# INFO:root:Train Epoch: 4 [128/1295 (9%)]	Loss: 7552.396973
# INFO:root:Train Epoch: 4 [256/1295 (18%)]	Loss: 74769.554688
# INFO:root:Train Epoch: 4 [384/1295 (27%)]	Loss: 27642.994141
# INFO:root:Train Epoch: 4 [512/1295 (36%)]	Loss: 5690.795898
# INFO:root:Train Epoch: 4 [640/1295 (45%)]	Loss: 41024.207031
# INFO:root:Train Epoch: 4 [768/1295 (55%)]	Loss: 47912.097656
# INFO:root:Train Epoch: 4 [896/1295 (64%)]	Loss: 14341.281250
# INFO:root:Train Epoch: 4 [1024/1295 (73%)]	Loss: 6294.805664
# INFO:root:Train Epoch: 4 [1152/1295 (82%)]	Loss: 32209.931641
# INFO:root:Train Epoch: 4 [150/1295 (91%)]	Loss: 23826.248047
# 11it [00:00, 157.09it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 5 [0/1295 (0%)]	Loss: 3906.630859
# INFO:root:Train Epoch: 5 [128/1295 (9%)]	Loss: 28460.470703
# INFO:root:Train Epoch: 5 [256/1295 (18%)]	Loss: 26078.097656
# INFO:root:Train Epoch: 5 [384/1295 (27%)]	Loss: 9085.921875
# INFO:root:Train Epoch: 5 [512/1295 (36%)]	Loss: 6296.734375
# INFO:root:Train Epoch: 5 [640/1295 (45%)]	Loss: 22391.054688
# INFO:root:Train Epoch: 5 [768/1295 (55%)]	Loss: 10031.474609
# INFO:root:Train Epoch: 5 [896/1295 (64%)]	Loss: 2905.390137
# INFO:root:Train Epoch: 5 [1024/1295 (73%)]	Loss: 11749.203125
# INFO:root:Train Epoch: 5 [1152/1295 (82%)]	Loss: 15994.541016
# INFO:root:Train Epoch: 5 [150/1295 (91%)]	Loss: 9209.764648
# 11it [00:00, 157.09it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 6 [0/1295 (0%)]	Loss: 5463.606445
# INFO:root:Train Epoch: 6 [128/1295 (9%)]	Loss: 15219.248047
# INFO:root:Train Epoch: 6 [256/1295 (18%)]	Loss: 8624.916992
# INFO:root:Train Epoch: 6 [384/1295 (27%)]	Loss: 3537.756348
# INFO:root:Train Epoch: 6 [512/1295 (36%)]	Loss: 10424.953125
# INFO:root:Train Epoch: 6 [640/1295 (45%)]	Loss: 10612.938477
# INFO:root:Train Epoch: 6 [768/1295 (55%)]	Loss: 4209.113770
# INFO:root:Train Epoch: 6 [896/1295 (64%)]	Loss: 4427.086914
# INFO:root:Train Epoch: 6 [1024/1295 (73%)]	Loss: 11804.854492
# INFO:root:Train Epoch: 6 [1152/1295 (82%)]	Loss: 4409.988770
# INFO:root:Train Epoch: 6 [150/1295 (91%)]	Loss: 3178.760254
# 11it [00:00, 159.37it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 7 [0/1295 (0%)]	Loss: 5509.588379
# INFO:root:Train Epoch: 7 [128/1295 (9%)]	Loss: 5271.127441
# INFO:root:Train Epoch: 7 [256/1295 (18%)]	Loss: 3605.824463
# INFO:root:Train Epoch: 7 [384/1295 (27%)]	Loss: 4321.221191
# INFO:root:Train Epoch: 7 [512/1295 (36%)]	Loss: 4533.063477
# INFO:root:Train Epoch: 7 [640/1295 (45%)]	Loss: 4066.531494
# INFO:root:Train Epoch: 7 [768/1295 (55%)]	Loss: 2906.225586
# INFO:root:Train Epoch: 7 [896/1295 (64%)]	Loss: 4158.090332
# INFO:root:Train Epoch: 7 [1024/1295 (73%)]	Loss: 3944.281982
# INFO:root:Train Epoch: 7 [1152/1295 (82%)]	Loss: 2895.931152
# INFO:root:Train Epoch: 7 [150/1295 (91%)]	Loss: 4319.053711
# 11it [00:00, 159.37it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 8 [0/1295 (0%)]	Loss: 3907.610596
# INFO:root:Train Epoch: 8 [128/1295 (9%)]	Loss: 3004.984131
# INFO:root:Train Epoch: 8 [256/1295 (18%)]	Loss: 3280.833252
# INFO:root:Train Epoch: 8 [384/1295 (27%)]	Loss: 3234.412598
# INFO:root:Train Epoch: 8 [512/1295 (36%)]	Loss: 3028.792725
# INFO:root:Train Epoch: 8 [640/1295 (45%)]	Loss: 3203.614014
# INFO:root:Train Epoch: 8 [768/1295 (55%)]	Loss: 2909.790527
# INFO:root:Train Epoch: 8 [896/1295 (64%)]	Loss: 2880.769531
# INFO:root:Train Epoch: 8 [1024/1295 (73%)]	Loss: 3643.294189
# INFO:root:Train Epoch: 8 [1152/1295 (82%)]	Loss: 2937.704346
# INFO:root:Train Epoch: 8 [150/1295 (91%)]	Loss: 2887.611328
# 11it [00:00, 164.13it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 9 [0/1295 (0%)]	Loss: 3889.669678
# INFO:root:Train Epoch: 9 [128/1295 (9%)]	Loss: 2693.266846
# INFO:root:Train Epoch: 9 [256/1295 (18%)]	Loss: 3133.254639
# INFO:root:Train Epoch: 9 [384/1295 (27%)]	Loss: 3818.975586
# INFO:root:Train Epoch: 9 [512/1295 (36%)]	Loss: 2974.601318
# INFO:root:Train Epoch: 9 [640/1295 (45%)]	Loss: 2912.171387
# INFO:root:Train Epoch: 9 [768/1295 (55%)]	Loss: 2861.329590
# INFO:root:Train Epoch: 9 [896/1295 (64%)]	Loss: 2903.660889
# INFO:root:Train Epoch: 9 [1024/1295 (73%)]	Loss: 3163.975586
# INFO:root:Train Epoch: 9 [1152/1295 (82%)]	Loss: 3254.091309
# INFO:root:Train Epoch: 9 [150/1295 (91%)]	Loss: 2958.308105
# 11it [00:00, 157.09it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 10 [0/1295 (0%)]	Loss: 2750.418945
# INFO:root:Train Epoch: 10 [128/1295 (9%)]	Loss: 3507.128662
# INFO:root:Train Epoch: 10 [256/1295 (18%)]	Loss: 3460.094238
# INFO:root:Train Epoch: 10 [384/1295 (27%)]	Loss: 2861.729492
# INFO:root:Train Epoch: 10 [512/1295 (36%)]	Loss: 3010.562256
# INFO:root:Train Epoch: 10 [640/1295 (45%)]	Loss: 3592.557861
# INFO:root:Train Epoch: 10 [768/1295 (55%)]	Loss: 3196.206543
# INFO:root:Train Epoch: 10 [896/1295 (64%)]	Loss: 2837.236084
# INFO:root:Train Epoch: 10 [1024/1295 (73%)]	Loss: 3484.997803
# INFO:root:Train Epoch: 10 [1152/1295 (82%)]	Loss: 3625.173340
# INFO:root:Train Epoch: 10 [150/1295 (91%)]	Loss: 2333.475830
# 11it [00:00, 157.09it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 11 [0/1295 (0%)]	Loss: 2995.411377
# INFO:root:Train Epoch: 11 [128/1295 (9%)]	Loss: 4201.306152
# INFO:root:Train Epoch: 11 [256/1295 (18%)]	Loss: 3087.853027
# INFO:root:Train Epoch: 11 [384/1295 (27%)]	Loss: 3088.210449
# INFO:root:Train Epoch: 11 [512/1295 (36%)]	Loss: 3732.041016
# INFO:root:Train Epoch: 11 [640/1295 (45%)]	Loss: 3039.617432
# INFO:root:Train Epoch: 11 [768/1295 (55%)]	Loss: 3299.623779
# INFO:root:Train Epoch: 11 [896/1295 (64%)]	Loss: 3454.050781
# INFO:root:Train Epoch: 11 [1024/1295 (73%)]	Loss: 3706.852539
# INFO:root:Train Epoch: 11 [1152/1295 (82%)]	Loss: 2854.854736
# INFO:root:Train Epoch: 11 [150/1295 (91%)]	Loss: 2938.687500
# 11it [00:00, 164.13it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 12 [0/1295 (0%)]	Loss: 3479.534424
# INFO:root:Train Epoch: 12 [128/1295 (9%)]	Loss: 3016.841553
# INFO:root:Train Epoch: 12 [256/1295 (18%)]	Loss: 2928.164551
# INFO:root:Train Epoch: 12 [384/1295 (27%)]	Loss: 2953.731201
# INFO:root:Train Epoch: 12 [512/1295 (36%)]	Loss: 3848.784668
# INFO:root:Train Epoch: 12 [640/1295 (45%)]	Loss: 3286.255371
# INFO:root:Train Epoch: 12 [768/1295 (55%)]	Loss: 3492.727783
# INFO:root:Train Epoch: 12 [896/1295 (64%)]	Loss: 4192.509277
# INFO:root:Train Epoch: 12 [1024/1295 (73%)]	Loss: 3090.323975
# INFO:root:Train Epoch: 12 [1152/1295 (82%)]	Loss: 3098.171143
# INFO:root:Train Epoch: 12 [150/1295 (91%)]	Loss: 3370.771484
# 11it [00:00, 161.72it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 13 [0/1295 (0%)]	Loss: 4072.211914
# INFO:root:Train Epoch: 13 [128/1295 (9%)]	Loss: 3116.065918
# INFO:root:Train Epoch: 13 [256/1295 (18%)]	Loss: 3621.731934
# INFO:root:Train Epoch: 13 [384/1295 (27%)]	Loss: 3171.638428
# INFO:root:Train Epoch: 13 [512/1295 (36%)]	Loss: 2867.631104
# INFO:root:Train Epoch: 13 [640/1295 (45%)]	Loss: 3001.873291
# INFO:root:Train Epoch: 13 [768/1295 (55%)]	Loss: 3034.525391
# INFO:root:Train Epoch: 13 [896/1295 (64%)]	Loss: 3617.077637
# INFO:root:Train Epoch: 13 [1024/1295 (73%)]	Loss: 3514.503662
# INFO:root:Train Epoch: 13 [1152/1295 (82%)]	Loss: 2853.541992
# INFO:root:Train Epoch: 13 [150/1295 (91%)]	Loss: 3632.832764
# 11it [00:00, 166.62it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 14 [0/1295 (0%)]	Loss: 3685.947510
# INFO:root:Train Epoch: 14 [128/1295 (9%)]	Loss: 3254.975586
# INFO:root:Train Epoch: 14 [256/1295 (18%)]	Loss: 3066.198486
# INFO:root:Train Epoch: 14 [384/1295 (27%)]	Loss: 4454.963867
# INFO:root:Train Epoch: 14 [512/1295 (36%)]	Loss: 3215.729492
# INFO:root:Train Epoch: 14 [640/1295 (45%)]	Loss: 2889.192383
# INFO:root:Train Epoch: 14 [768/1295 (55%)]	Loss: 3792.214111
# INFO:root:Train Epoch: 14 [896/1295 (64%)]	Loss: 3701.107422
# INFO:root:Train Epoch: 14 [1024/1295 (73%)]	Loss: 2742.202637
# INFO:root:Train Epoch: 14 [1152/1295 (82%)]	Loss: 3546.976074
# INFO:root:Train Epoch: 14 [150/1295 (91%)]	Loss: 5932.184570
# 11it [00:00, 166.62it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 15 [0/1295 (0%)]	Loss: 3111.406982
# INFO:root:Train Epoch: 15 [128/1295 (9%)]	Loss: 4609.274414
# INFO:root:Train Epoch: 15 [256/1295 (18%)]	Loss: 3608.309814
# INFO:root:Train Epoch: 15 [384/1295 (27%)]	Loss: 2875.639160
# INFO:root:Train Epoch: 15 [512/1295 (36%)]	Loss: 3803.056641
# INFO:root:Train Epoch: 15 [640/1295 (45%)]	Loss: 3906.545166
# INFO:root:Train Epoch: 15 [768/1295 (55%)]	Loss: 2837.578125
# INFO:root:Train Epoch: 15 [896/1295 (64%)]	Loss: 3545.525146
# INFO:root:Train Epoch: 15 [1024/1295 (73%)]	Loss: 4125.968750
# INFO:root:Train Epoch: 15 [1152/1295 (82%)]	Loss: 3110.565674
# INFO:root:Train Epoch: 15 [150/1295 (91%)]	Loss: 3127.337891
# 11it [00:00, 174.55it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 16 [0/1295 (0%)]	Loss: 3222.070801
# INFO:root:Train Epoch: 16 [128/1295 (9%)]	Loss: 3094.406006
# INFO:root:Train Epoch: 16 [256/1295 (18%)]	Loss: 3042.712891
# INFO:root:Train Epoch: 16 [384/1295 (27%)]	Loss: 3108.031250
# INFO:root:Train Epoch: 16 [512/1295 (36%)]	Loss: 2974.020752
# INFO:root:Train Epoch: 16 [640/1295 (45%)]	Loss: 3113.282715
# INFO:root:Train Epoch: 16 [768/1295 (55%)]	Loss: 3128.117188
# INFO:root:Train Epoch: 16 [896/1295 (64%)]	Loss: 2644.072754
# INFO:root:Train Epoch: 16 [1024/1295 (73%)]	Loss: 3016.089111
# INFO:root:Train Epoch: 16 [1152/1295 (82%)]	Loss: 2961.474609
# INFO:root:Train Epoch: 16 [150/1295 (91%)]	Loss: 2752.917236
# 11it [00:00, 171.82it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 17 [0/1295 (0%)]	Loss: 3198.791016
# INFO:root:Train Epoch: 17 [128/1295 (9%)]	Loss: 2880.330811
# INFO:root:Train Epoch: 17 [256/1295 (18%)]	Loss: 3096.642822
# INFO:root:Train Epoch: 17 [384/1295 (27%)]	Loss: 3021.510010
# INFO:root:Train Epoch: 17 [512/1295 (36%)]	Loss: 3030.496826
# INFO:root:Train Epoch: 17 [640/1295 (45%)]	Loss: 3152.462891
# INFO:root:Train Epoch: 17 [768/1295 (55%)]	Loss: 3186.951660
# INFO:root:Train Epoch: 17 [896/1295 (64%)]	Loss: 2867.838135
# INFO:root:Train Epoch: 17 [1024/1295 (73%)]	Loss: 2850.817139
# INFO:root:Train Epoch: 17 [1152/1295 (82%)]	Loss: 2863.230225
# INFO:root:Train Epoch: 17 [150/1295 (91%)]	Loss: 3115.657715
# 11it [00:00, 166.62it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 18 [0/1295 (0%)]	Loss: 3048.414062
# INFO:root:Train Epoch: 18 [128/1295 (9%)]	Loss: 2926.156006
# INFO:root:Train Epoch: 18 [256/1295 (18%)]	Loss: 3081.472656
# INFO:root:Train Epoch: 18 [384/1295 (27%)]	Loss: 2937.168213
# INFO:root:Train Epoch: 18 [512/1295 (36%)]	Loss: 3101.294189
# INFO:root:Train Epoch: 18 [640/1295 (45%)]	Loss: 2861.351807
# INFO:root:Train Epoch: 18 [768/1295 (55%)]	Loss: 3291.537842
# INFO:root:Train Epoch: 18 [896/1295 (64%)]	Loss: 2797.616211
# INFO:root:Train Epoch: 18 [1024/1295 (73%)]	Loss: 2724.941895
# INFO:root:Train Epoch: 18 [1152/1295 (82%)]	Loss: 3307.946289
# INFO:root:Train Epoch: 18 [150/1295 (91%)]	Loss: 2482.184326
# 11it [00:00, 169.18it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 19 [0/1295 (0%)]	Loss: 2976.315918
# INFO:root:Train Epoch: 19 [128/1295 (9%)]	Loss: 3012.501953
# INFO:root:Train Epoch: 19 [256/1295 (18%)]	Loss: 3078.300781
# INFO:root:Train Epoch: 19 [384/1295 (27%)]	Loss: 3192.227295
# INFO:root:Train Epoch: 19 [512/1295 (36%)]	Loss: 2808.432373
# INFO:root:Train Epoch: 19 [640/1295 (45%)]	Loss: 3144.574219
# INFO:root:Train Epoch: 19 [768/1295 (55%)]	Loss: 2801.555664
# INFO:root:Train Epoch: 19 [896/1295 (64%)]	Loss: 3008.475098
# INFO:root:Train Epoch: 19 [1024/1295 (73%)]	Loss: 3108.358643
# INFO:root:Train Epoch: 19 [1152/1295 (82%)]	Loss: 2997.219971
# INFO:root:Train Epoch: 19 [150/1295 (91%)]	Loss: 2836.202148
# 11it [00:00, 174.55it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 20 [0/1295 (0%)]	Loss: 2977.496826
# INFO:root:Train Epoch: 20 [128/1295 (9%)]	Loss: 3005.428955
# INFO:root:Train Epoch: 20 [256/1295 (18%)]	Loss: 2958.319092
# INFO:root:Train Epoch: 20 [384/1295 (27%)]	Loss: 3018.845947
# INFO:root:Train Epoch: 20 [512/1295 (36%)]	Loss: 3219.588623
# INFO:root:Train Epoch: 20 [640/1295 (45%)]	Loss: 2915.990967
# INFO:root:Train Epoch: 20 [768/1295 (55%)]	Loss: 2854.273682
# INFO:root:Train Epoch: 20 [896/1295 (64%)]	Loss: 3375.755859
# INFO:root:Train Epoch: 20 [1024/1295 (73%)]	Loss: 3056.355469
# INFO:root:Train Epoch: 20 [1152/1295 (82%)]	Loss: 2930.231201
# INFO:root:Train Epoch: 20 [150/1295 (91%)]	Loss: 2596.463379
# 11it [00:00, 171.82it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 21 [0/1295 (0%)]	Loss: 3490.052246
# INFO:root:Train Epoch: 21 [128/1295 (9%)]	Loss: 2948.284180
# INFO:root:Train Epoch: 21 [256/1295 (18%)]	Loss: 2969.087891
# INFO:root:Train Epoch: 21 [384/1295 (27%)]	Loss: 3378.174561
# INFO:root:Train Epoch: 21 [512/1295 (36%)]	Loss: 3327.802734
# INFO:root:Train Epoch: 21 [640/1295 (45%)]	Loss: 2971.153809
# INFO:root:Train Epoch: 21 [768/1295 (55%)]	Loss: 3236.577148
# INFO:root:Train Epoch: 21 [896/1295 (64%)]	Loss: 3389.902832
# INFO:root:Train Epoch: 21 [1024/1295 (73%)]	Loss: 3094.142334
# INFO:root:Train Epoch: 21 [1152/1295 (82%)]	Loss: 3232.257812
# INFO:root:Train Epoch: 21 [150/1295 (91%)]	Loss: 3969.848877
# 11it [00:00, 171.82it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 22 [0/1295 (0%)]	Loss: 2819.927246
# INFO:root:Train Epoch: 22 [128/1295 (9%)]	Loss: 3770.876465
# INFO:root:Train Epoch: 22 [256/1295 (18%)]	Loss: 3787.698730
# INFO:root:Train Epoch: 22 [384/1295 (27%)]	Loss: 2789.187012
# INFO:root:Train Epoch: 22 [512/1295 (36%)]	Loss: 2958.236328
# INFO:root:Train Epoch: 22 [640/1295 (45%)]	Loss: 3287.759766
# INFO:root:Train Epoch: 22 [768/1295 (55%)]	Loss: 3196.600830
# INFO:root:Train Epoch: 22 [896/1295 (64%)]	Loss: 2738.629150
# INFO:root:Train Epoch: 22 [1024/1295 (73%)]	Loss: 2777.349854
# INFO:root:Train Epoch: 22 [1152/1295 (82%)]	Loss: 3537.657227
# INFO:root:Train Epoch: 22 [150/1295 (91%)]	Loss: 2811.888916
# 11it [00:00, 174.55it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 23 [0/1295 (0%)]	Loss: 3145.798340
# INFO:root:Train Epoch: 23 [128/1295 (9%)]	Loss: 3191.126465
# INFO:root:Train Epoch: 23 [256/1295 (18%)]	Loss: 3139.327637
# INFO:root:Train Epoch: 23 [384/1295 (27%)]	Loss: 3235.902588
# INFO:root:Train Epoch: 23 [512/1295 (36%)]	Loss: 2857.462402
# INFO:root:Train Epoch: 23 [640/1295 (45%)]	Loss: 3249.699219
# INFO:root:Train Epoch: 23 [768/1295 (55%)]	Loss: 2608.369141
# INFO:root:Train Epoch: 23 [896/1295 (64%)]	Loss: 3121.729004
# INFO:root:Train Epoch: 23 [1024/1295 (73%)]	Loss: 3015.380859
# INFO:root:Train Epoch: 23 [1152/1295 (82%)]	Loss: 2980.010742
# INFO:root:Train Epoch: 23 [150/1295 (91%)]	Loss: 2964.577393
# 11it [00:00, 174.55it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 24 [0/1295 (0%)]	Loss: 2943.735840
# INFO:root:Train Epoch: 24 [128/1295 (9%)]	Loss: 2978.515625
# INFO:root:Train Epoch: 24 [256/1295 (18%)]	Loss: 3171.116455
# INFO:root:Train Epoch: 24 [384/1295 (27%)]	Loss: 2993.854980
# INFO:root:Train Epoch: 24 [512/1295 (36%)]	Loss: 3096.253174
# INFO:root:Train Epoch: 24 [640/1295 (45%)]	Loss: 2991.633057
# INFO:root:Train Epoch: 24 [768/1295 (55%)]	Loss: 2929.350830
# INFO:root:Train Epoch: 24 [896/1295 (64%)]	Loss: 2860.183594
# INFO:root:Train Epoch: 24 [1024/1295 (73%)]	Loss: 3235.455078
# INFO:root:Train Epoch: 24 [1152/1295 (82%)]	Loss: 3214.070068
# INFO:root:Train Epoch: 24 [150/1295 (91%)]	Loss: 2579.539062
# 11it [00:00, 177.37it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 25 [0/1295 (0%)]	Loss: 3941.290771
# INFO:root:Train Epoch: 25 [128/1295 (9%)]	Loss: 3541.194336
# INFO:root:Train Epoch: 25 [256/1295 (18%)]	Loss: 2980.951416
# INFO:root:Train Epoch: 25 [384/1295 (27%)]	Loss: 3619.207764
# INFO:root:Train Epoch: 25 [512/1295 (36%)]	Loss: 3189.089844
# INFO:root:Train Epoch: 25 [640/1295 (45%)]	Loss: 2822.427002
# INFO:root:Train Epoch: 25 [768/1295 (55%)]	Loss: 3029.820312
# INFO:root:Train Epoch: 25 [896/1295 (64%)]	Loss: 3399.659180
# INFO:root:Train Epoch: 25 [1024/1295 (73%)]	Loss: 3468.880859
# INFO:root:Train Epoch: 25 [1152/1295 (82%)]	Loss: 2892.894531
# INFO:root:Train Epoch: 25 [150/1295 (91%)]	Loss: 2994.499023
# 11it [00:00, 177.36it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 26 [0/1295 (0%)]	Loss: 3362.529297
# INFO:root:Train Epoch: 26 [128/1295 (9%)]	Loss: 2883.451904
# INFO:root:Train Epoch: 26 [256/1295 (18%)]	Loss: 3387.964844
# INFO:root:Train Epoch: 26 [384/1295 (27%)]	Loss: 3831.336670
# INFO:root:Train Epoch: 26 [512/1295 (36%)]	Loss: 3083.058350
# INFO:root:Train Epoch: 26 [640/1295 (45%)]	Loss: 3371.934814
# INFO:root:Train Epoch: 26 [768/1295 (55%)]	Loss: 2984.990234
# INFO:root:Train Epoch: 26 [896/1295 (64%)]	Loss: 2945.246826
# INFO:root:Train Epoch: 26 [1024/1295 (73%)]	Loss: 3540.703369
# INFO:root:Train Epoch: 26 [1152/1295 (82%)]	Loss: 3165.694336
# INFO:root:Train Epoch: 26 [150/1295 (91%)]	Loss: 3993.942871
# 11it [00:00, 174.55it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 27 [0/1295 (0%)]	Loss: 3168.415771
# INFO:root:Train Epoch: 27 [128/1295 (9%)]	Loss: 2768.672607
# INFO:root:Train Epoch: 27 [256/1295 (18%)]	Loss: 3313.267822
# INFO:root:Train Epoch: 27 [384/1295 (27%)]	Loss: 3302.063965
# INFO:root:Train Epoch: 27 [512/1295 (36%)]	Loss: 3103.043213
# INFO:root:Train Epoch: 27 [640/1295 (45%)]	Loss: 3121.382080
# INFO:root:Train Epoch: 27 [768/1295 (55%)]	Loss: 2933.872070
# INFO:root:Train Epoch: 27 [896/1295 (64%)]	Loss: 2868.713379
# INFO:root:Train Epoch: 27 [1024/1295 (73%)]	Loss: 2950.789062
# INFO:root:Train Epoch: 27 [1152/1295 (82%)]	Loss: 2845.526123
# INFO:root:Train Epoch: 27 [150/1295 (91%)]	Loss: 4740.165527
# 11it [00:00, 171.82it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 28 [0/1295 (0%)]	Loss: 3011.701416
# INFO:root:Train Epoch: 28 [128/1295 (9%)]	Loss: 3673.866943
# INFO:root:Train Epoch: 28 [256/1295 (18%)]	Loss: 2964.767090
# INFO:root:Train Epoch: 28 [384/1295 (27%)]	Loss: 2781.392822
# INFO:root:Train Epoch: 28 [512/1295 (36%)]	Loss: 3155.386719
# INFO:root:Train Epoch: 28 [640/1295 (45%)]	Loss: 3103.676758
# INFO:root:Train Epoch: 28 [768/1295 (55%)]	Loss: 3197.261963
# INFO:root:Train Epoch: 28 [896/1295 (64%)]	Loss: 3272.351074
# INFO:root:Train Epoch: 28 [1024/1295 (73%)]	Loss: 3131.731689
# INFO:root:Train Epoch: 28 [1152/1295 (82%)]	Loss: 3005.228516
# INFO:root:Train Epoch: 28 [150/1295 (91%)]	Loss: 2325.061279
# 11it [00:00, 166.62it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 29 [0/1295 (0%)]	Loss: 2979.002441
# INFO:root:Train Epoch: 29 [128/1295 (9%)]	Loss: 3050.516846
# INFO:root:Train Epoch: 29 [256/1295 (18%)]	Loss: 3051.155518
# INFO:root:Train Epoch: 29 [384/1295 (27%)]	Loss: 2980.529053
# INFO:root:Train Epoch: 29 [512/1295 (36%)]	Loss: 2909.960938
# INFO:root:Train Epoch: 29 [640/1295 (45%)]	Loss: 2810.847412
# INFO:root:Train Epoch: 29 [768/1295 (55%)]	Loss: 3235.083496
# INFO:root:Train Epoch: 29 [896/1295 (64%)]	Loss: 3057.048584
# INFO:root:Train Epoch: 29 [1024/1295 (73%)]	Loss: 3085.222656
# INFO:root:Train Epoch: 29 [1152/1295 (82%)]	Loss: 3113.281006
# INFO:root:Train Epoch: 29 [150/1295 (91%)]	Loss: 2744.936768
# 11it [00:00, 169.18it/s]
# 0it [00:00, ?it/s]INFO:root:Train Epoch: 30 [0/1295 (0%)]	Loss: 3101.397705
# INFO:root:Train Epoch: 30 [128/1295 (9%)]	Loss: 3579.410645
# INFO:root:Train Epoch: 30 [256/1295 (18%)]	Loss: 3121.351807
# INFO:root:Train Epoch: 30 [384/1295 (27%)]	Loss: 3367.726074
# INFO:root:Train Epoch: 30 [512/1295 (36%)]	Loss: 3567.407227
# INFO:root:Train Epoch: 30 [640/1295 (45%)]	Loss: 3586.323730
# INFO:root:Train Epoch: 30 [768/1295 (55%)]	Loss: 3204.940186
# INFO:root:Train Epoch: 30 [896/1295 (64%)]	Loss: 3533.702393
# INFO:root:Train Epoch: 30 [1024/1295 (73%)]	Loss: 3141.517822
# INFO:root:Train Epoch: 30 [1152/1295 (82%)]	Loss: 3019.935547
# INFO:root:Train Epoch: 30 [150/1295 (91%)]	Loss: 3276.853271
# 11it [00:00, 169.18it/s]
